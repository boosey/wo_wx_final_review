# %%
# !flutter clean
# !flutter pub get
# !flutter build web
# Out:
# Deleting build...                                                         12ms
# Deleting .dart_tool...                                                    43ms
# Deleting Generated.xcconfig...                                             0ms
# Deleting flutter_export_environment.sh...                                  0ms
# Deleting ephemeral...                                                      0ms
# Resolving dependencies...
#   _fe_analyzer_shared 60.0.0 (65.0.0 available)
#   analyzer 5.12.0 (6.3.0 available)
#   analyzer_plugin 0.11.2 (0.11.3 available)
#   archive 3.3.9 (3.4.9 available)
#   build 2.3.1 (2.4.1 available)
#   build_daemon 3.1.1 (4.0.1 available)
#   build_modules 4.0.7 (5.0.5 available)
#   build_resolvers 2.3.2 (2.4.1 available)
#   build_runner 2.3.3 (2.4.7 available)
#   build_runner_core 7.2.7+1 (7.2.11 available)
#   build_web_compilers 3.2.7 (4.0.7 available)
#   built_value 8.6.2 (8.8.0 available)
#   code_builder 4.6.0 (4.8.0 available)
# ...

# %%
print("Enter the version tag")
ver_tag = input()
# !docker buildx build --platform linux/amd64 --push -t boosey/wowxfinalreview:{ver_tag} .
# Out:
# Enter the version tag
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/1)
# [+] Building 0.2s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 222B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:mainline-alpine   0.1s
# [+] Building 0.3s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 222B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:mainline-alpine   0.3s
# [+] Building 0.5s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 222B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:mainline-alpine   0.4s
# [+] Building 0.6s (1/2)
# ...
